# %% [markdown]
# # Import pandas library

# %%
import pandas as pd

# %% [markdown]
# # Sample Datasets

# %%
Data = {
   'Department': ['HR', 'IT', 'IT', 'HR', 'Finance'],
    'Salary': [40000, 60000, None, 45000, 70000]
}

# %%
df = pd.DataFrame(Data)

# %%
df.head(2)
# Out:
#   Department   Salary
# 0         HR  40000.0
# 1         IT  60000.0

# %% [markdown]
# # Remove missing Values

# %%
df = df.dropna()

# %%
df.head(4)
# Out:
#   Department   Salary
# 0         HR  40000.0
# 1         IT  60000.0
# 3         HR  45000.0
# 4    Finance  70000.0

# %% [markdown]
# # Grouping and Aggregation

# %%
Avg_Salary = df.groupby('Department')['Salary'].mean()

# %%
print("Average Salary by Department:")
print(Avg_Salary)
# Out:
# Average Salary by Department:
# Department
# Finance    70000.0
# HR         42500.0
# IT         60000.0
# Name: Salary, dtype: float64
